# %% [markdown]
# # Ejercicios Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Contar cuántos valores hay en una lista de enteros. Contar solo hasta el número 0.

# %%
nums = [6,8,5,2,0,6,5]
contador = 0
#Respuesta:
#Debe dar 5

# Solución 1
# nums.index(0) + 1

# Solución 2
for num in nums:
    contador += 1
    if num == 0:
        break
contador

# Solución 3
# nums_length = len(nums)
# pos = 0
# zero_found = False
# while(pos < nums_length and not zero_found):
#     contador += 1
#     zero_found = nums[pos] == 0
#     pos += 1
# contador
# Out:
# 5

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Sumar los valores que hay en una lista de enteros. Sumar solo hasta el número 0.

# %%
nums = [6,8,5,2,0,6,5]
suma = 0
#Respuesta:
#Debe dar 21

# Solución 1
# zero_position = nums.index(0)
# sum(nums[:zero_position])

# Solución 2
# for num in nums:
#     if num == 0:
#         break
#     suma += num
# suma

# Solución 3
nums_length = len(nums)
zero_found = False
pos = 0
while pos < nums_length and not zero_found:
    suma += nums[pos]
    zero_found = nums[pos] == 0
    pos += 1
suma
# Out:
# 21

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Calcular el valor medio de los valores que hay en una lista de enteros. Calcular solo hasta el número 0.

# %%
nums = [6,8,5,2,0,6,5]
suma = 0
contador = 0
#Respuesta:
#Debe dar 4.2

# Solución 1
# zero_position = nums.index(0) + 1
# sublist = nums[:zero_position]
# sublist_length = len(sublist)
# sum(sublist) / sublist_length

# Solución 2
# for num in nums:
#     suma += num
#     contador += 1
#     if num == 0:
#         break
# suma / contador

# Solución 3
zero_found = False
while contador < nums_length and not zero_found:
    num = nums[contador]
    suma += num
    contador += 1
    zero_found = num == 0
suma / contador
# Out:
# [6, 8, 5, 2, 0]
# 4.2

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Elimina las "a" del siguiente texto:

# %%
texto = "Las variables son almacenes de datos que persisten en memoria. Cuando accedemos a una variable en realidad estamos accediendo a un puntero en memoria que almacena el valor que nos interesa. "
#Respuesta

new_text = ''
texto_length = len(texto)

# Solución 1
# texto.replace('a', '')

# Solución 2
# for letra in texto:
#     if letra != 'a':
#         new_text += letra
# new_text

# Solución 3
pos = 0

while pos < texto_length:
    if texto[pos] != 'a':
        new_text += texto[pos]
    pos += 1
new_text
# Out:
# 'Ls vribles son lmcenes de dtos que persisten en memori. Cundo ccedemos  un vrible en relidd estmos ccediendo  un puntero en memori que lmcen el vlor que nos interes. '

# %% [markdown]
# ## Ejercicio 5 (Opcional)

# %% [markdown]
# Crear una lista a partir de una secuencia de valores de entrada terminada en *.
# Una vez creada, modificarla elevando al cuadrado todos los pares y al cubo todos los impares, y mostrarla.

# %%
lista = [3,56,6,7,"*",2,78]
#Respuesta:
#Debe dar [27, 3136, 36, 343]

lista_final = []

# Solución 1
# end_index = lista.index('*')
# sublista = lista[:end_index]
# lista_final = [num ** 2 if num % 2 == 0 else num ** 3 for num in sublista]
# lista_final

# Solución 2
for num in lista:
    if num == '*':
        break
    lista_final.append(num ** 2 if num % 2 == 0 else num ** 3)
lista_final

# Solución 3
# pos = 0
# lista_length = len(lista)
# asterisk_found = False
# while pos < lista_length and not asterisk_found:
#     num = lista[pos]
#     asterisk_found = num == '*'
#     if not asterisk_found:
#         lista_final.append(num ** 2 if num % 2 == 0 else num ** 3)
#     pos += 1
# lista_final
# Out:
# [27, 3136, 36, 343]
